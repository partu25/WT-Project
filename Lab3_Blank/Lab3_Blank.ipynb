# %% [markdown]
# <pre>
# <center><b><h1>Machine Learning</b></center>
#
# <center><b><h1>Lab - 3</b></center>
# <pre>

# %% [markdown]
# # 📱 Lab: Scikit-Learn Fundamentals (Google Play Store)
#
# **Objective:** Transition from manual data cleaning to automated Machine Learning preprocessing using Scikit-Learn.
#
# **Prerequisites:**
# * Ensure you have the `googleplaystore_cleaned.csv` file (from the previous lab) in this folder.

# %% [markdown]
# ### 1. Load Preprocessed Data
# **Instruction:** Load the dataset you cleaned in the previous lab. This dataset should already have `Installs`, `Price`, and `Reviews` converted to numbers.

# %%
import sklearn
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('lab3.csv')

# %%
df
# Out:
#        Unnamed: 0                                                App  \
# 0               0     Photo Editor & Candy Camera & Grid & ScrapBook
# 1               1                                Coloring book moana
# 2               2  U Launcher Lite – FREE Live Cool Themes, Hide ...
# 3               3                              Sketch - Draw & Paint
# 4               4              Pixel Draw - Number Art Coloring Book
# ...           ...                                                ...
# 10341       10836                                   Sya9a Maroc - FR
# 10342       10837                   Fr. Mike Schmitz Audio Teachings
# 10343       10838                             Parkinson Exercices FR
# 10344       10839                      The SCP Foundation DB fr nn5n
# 10345       10840      iHoroscope - 2018 Daily Horoscope & Astrology
#
#                   Category  Rating   Reviews        Size    Installs  Type  \
# 0           ART_AND_DESIGN     4.1     159.0     10000.0     10000.0  Free
# 1           ART_AND_DESIGN     3.9     967.0    500000.0    500000.0  Free
# 2           ART_AND_DESIGN     4.7   87510.0   5000000.0   5000000.0  Free
# 3           ART_AND_DESIGN     4.5  215644.0  50000000.0  50000000.0  Free
# 4           ART_AND_DESIGN     4.3     967.0    100000.0    100000.0  Free
# ...                    ...     ...       ...         ...         ...   ...
# 10341               FAMILY     4.5      38.0      5000.0      5000.0  Free
# 10342               FAMILY     5.0       4.0       100.0       100.0  Free
# 10343              MEDICAL     4.3       3.0      1000.0      1000.0  Free
# 10344  BOOKS_AND_REFERENCE     4.5     114.0      1000.0      1000.0  Free
# 10345            LIFESTYLE     4.5  398307.0  10000000.0  10000000.0  Free
#
#        Price Content Rating                     Genres      Last Updated  \
# 0        0.0       Everyone               Art & Design   January 7, 2018
# 1        0.0       Everyone  Art & Design;Pretend Play  January 15, 2018
# 2        0.0       Everyone               Art & Design    August 1, 2018
# 3        0.0           Teen               Art & Design      June 8, 2018
# 4        0.0       Everyone    Art & Design;Creativity     June 20, 2018
# ...      ...            ...                        ...               ...
# 10341    0.0       Everyone                  Education     July 25, 2017
# 10342    0.0       Everyone                  Education      July 6, 2018
# 10343    0.0       Everyone                    Medical  January 20, 2017
# 10344    0.0     Mature 17+          Books & Reference  January 19, 2015
# 10345    0.0       Everyone                  Lifestyle     July 25, 2018
#
#               Current Ver         Android Ver
# 0                   1.0.0        4.0.3 and up
# 1                   2.0.0        4.0.3 and up
# 2                   1.2.4        4.0.3 and up
# 3      Varies with device          4.2 and up
# 4                     1.1          4.4 and up
# ...                   ...                 ...
# 10341                1.48          4.1 and up
# 10342                 1.0          4.1 and up
# 10343                 1.0          2.2 and up
# 10344  Varies with device  Varies with device
# 10345  Varies with device  Varies with device
#
# [10346 rows x 14 columns]

# %% [markdown]
# ### Intro to Scikit-Learn
# **What is Scikit-Learn?**
# It is the standard library for Machine Learning in Python. We use it for:
# 1.  **Preprocessing:** Scaling numbers and encoding text.
# 2.  **Modeling:** Training algorithms.
# 3.  **Evaluation:** Checking accuracy.
#
# **Task:** Import `sklearn` and check the version.

# %%
sklearn.__version__
# Out:
# '1.5.1'

# %% [markdown]
# ### 3.  Train_Test_Split
# **Concept:** We split data to prevent "Overfitting". The model learns from the **Train** set and is tested on the **Test** set.
#
# **Task:**
# 1. Define `X` (Features: everything except Rating/App) and `y` (Target: Rating).
# 2. Split the data (80% Train, 20% Test).

# %%
from sklearn.model_selection import train_test_split
X = df.drop(['Rating','App'],axis=1)
y = df['Rating']

X_train,y_train,X_test,y_test = train_test_split(X,y,test_size=0.2,random_state=1)

print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (8276, 12)
# (2070, 12)
# (8276,)
# (2070,)

# %% [markdown]
# ### 4. 📏 Scaling Numerical Data (StandardScaler)
# **Concept:** `Installs` (Millions) are much larger than `Rating` (1-5). We scale them so the model treats them equally.
#
# **Task:** Use `StandardScaler` on the numerical columns.

# %%
df.head()
# Out:
#    Unnamed: 0                                                App  \
# 0           0     Photo Editor & Candy Camera & Grid & ScrapBook
# 1           1                                Coloring book moana
# 2           2  U Launcher Lite – FREE Live Cool Themes, Hide ...
# 3           3                              Sketch - Draw & Paint
# 4           4              Pixel Draw - Number Art Coloring Book
#
#          Category  Rating   Reviews        Size    Installs  Type  Price  \
# 0  ART_AND_DESIGN     4.1     159.0     10000.0     10000.0  Free    0.0
# 1  ART_AND_DESIGN     3.9     967.0    500000.0    500000.0  Free    0.0
# 2  ART_AND_DESIGN     4.7   87510.0   5000000.0   5000000.0  Free    0.0
# 3  ART_AND_DESIGN     4.5  215644.0  50000000.0  50000000.0  Free    0.0
# 4  ART_AND_DESIGN     4.3     967.0    100000.0    100000.0  Free    0.0
#
#   Content Rating                     Genres      Last Updated  \
# 0       Everyone               Art & Design   January 7, 2018
# 1       Everyone  Art & Design;Pretend Play  January 15, 2018
# 2       Everyone               Art & Design    August 1, 2018
# 3           Teen               Art & Design      June 8, 2018
# 4       Everyone    Art & Design;Creativity     June 20, 2018
#
#           Current Ver   Android Ver
# 0               1.0.0  4.0.3 and up
# 1               2.0.0  4.0.3 and up
# 2               1.2.4  4.0.3 and up
# 3  Varies with device    4.2 and up
# 4                 1.1    4.4 and up

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

num_col = ['Reviews','Size','Installs','Price']

train_scaled =scaler.fit_transform(X_train[num_col])

train_scaled
# Out:
# array([[-0.150802  , -0.17824662, -0.17824662, -0.06350339],
#        [-0.14136979, -0.16740491, -0.16740491, -0.06350339],
#        [-0.14277156, -0.05898785, -0.05898785, -0.06350339],
#        ...,
#        [-0.14910585, -0.17342808, -0.17342808, -0.06350339],
#        [-0.14544546, -0.16740491, -0.16740491, -0.06350339],
#        [-0.14096257, -0.11921955, -0.11921955, -0.06350339]])

# %% [markdown]
# ### 5. 🔠 Encoding Categorical Data
# **Concept:** Models need numbers, not text like "Business" or "Teen".
#
# **Method A: Pandas `get_dummies` (Simple)**

# %%
df['Content Rating'].value_counts()
# Out:
# Content Rating
# Everyone           8372
# Teen               1146
# Mature 17+          447
# Everyone 10+        376
# Adults only 18+       3
# Unrated               2
# Name: count, dtype: int64

# %%
dummes = pd.get_dummies(X_train['Content Rating'])
dummes.head()
# Out:
#       Adults only 18+  Everyone  Everyone 10+  Mature 17+   Teen
# 9296            False      True         False       False  False
# 9562            False     False          True       False  False
# 2844            False      True         False       False  False
# 4410            False      True         False       False  False
# 255             False      True         False       False  False

# %% [markdown]
# **Method B: Sklearn `OneHotEncoder` (Professional)**

# %%
from sklearn.preprocessing import OneHotEncoder
ohe = OneHotEncoder()
ohe_train = ohe.fit_transform(X_train[['Category']])
ohe_train
# Out:
# <8276x33 sparse matrix of type '<class 'numpy.float64'>'
# 	with 8276 stored elements in Compressed Sparse Row format>

# %% [markdown]
# ### 6. 🚀 The Full Pipeline: ColumnTransformer
# **Concept:** Instead of doing steps 4 and 5 manually, we wrap them in one object.
#
# **Task:** Create a `ColumnTransformer` that Scales numerical data AND Encodes categorical data at the same time.

# %%
from sklearn.compose import ColumnTransformer

# %%
numeric_features = ['Reviews', 'Size', 'Installs', 'Price']
categorical_features = ['Category', 'Content Rating']

preprocesser = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), numeric_features),
        ('cat',OneHotEncoder(),categorical_features)
        
    ]
)

# %%
from sklearn.pipeline import Pipeline

# %%
pipline = Pipeline(steps = [('preprocesser', preprocesser)])

# %%
from sklearn import set_config

# %%
set_config(display='diagram')
pipline
# Out:
# Pipeline(steps=[('preprocesser',
#                  ColumnTransformer(transformers=[('num', StandardScaler(),
#                                                   ['Reviews', 'Size',
#                                                    'Installs', 'Price']),
#                                                  ('cat', OneHotEncoder(),
#                                                   ['Category',
#                                                    'Content Rating'])]))])

# %%
X = df[numeric_features + categorical_features]
X_processed = Pipline.
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[108], line 2
#       1 X = df[numeric_features + categorical_features]
# ----> 2 X_processed = Pipline.transform(X)
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\_available_if.py:40, in _AvailableIfDescriptor.__get__(self, obj, owner)
#      36 def __get__(self, obj, owner=None):
#      37     if obj is not None:
#      38         # delegate only on instances, not the classes.
#      39         # this is to allow access to the docstrings.
# ---> 40         self._check(obj, owner=owner)
#      41         out = MethodType(self.fn, obj)
#      43     else:
#      44         # This makes it possible to use the decorated method as an unbound method,
#      45         # for instance when monkeypatching.
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\_available_if.py:34, in _AvailableIfDescriptor._check(self, obj, owner)
#      31     raise AttributeError(attr_err_msg) from e
#      33 if not check_result:
# ---> 34     raise AttributeError(attr_err_msg)
#
# AttributeError: This 'Pipeline' has no attribute 'transform'
